# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from matplotlib.ticker import (AutoMinorLocator, MultipleLocator)
import matplotlib.ticker as ticker
from matplotlib import style

# the .LAS file has been converted into excel database and additional parameters has been calculated 
df=pd.read_excel('Volve Well Log Data (1).xlsx','15.9 - F - 11 T2')
df.head()
# Out:
#    Depth (m)  CALI (in)  DT (us/ft)  GR (API)  NPHI (v/v)  RACEHM (ohm.m)  \
# 0     2577.0      8.766     109.385    74.700       0.403           0.868
# 1     2577.1      8.703     110.133    72.799       0.399           0.783
# 2     2577.2      8.703     110.843    71.631       0.390           0.818
# 3     2577.3      8.672     111.010    69.900       0.385           0.815
# 4     2577.4      8.672     110.797    69.040       0.382           0.824
#
#    RACELM (ohm.m)  RD (ohm.m)  RHOB (g/cm3)  RM (ohm.m)  ...  RT (ohm.m)  \
# 0           0.823       0.750         2.347       0.751  ...       0.751
# 1           0.832       0.783         2.357       0.798  ...       0.798
# 2           0.831       0.776         2.360       0.750  ...       0.750
# 3           0.847       0.773         2.361       0.719  ...       0.719
# 4           0.858       0.757         2.363       0.693  ...       0.693
#
#         IGR  V shale (Larionov (1969) for old rocks)  V shale(Clavier (1971))  \
# ...

# %%
print(df)
# Out:
#       Depth (m)  CALI (in)  DT (us/ft)  GR (API)  NPHI (v/v)  RACEHM (ohm.m)  \
# 0        2577.0      8.766     109.385    74.700       0.403           0.868
# 1        2577.1      8.703     110.133    72.799       0.399           0.783
# 2        2577.2      8.703     110.843    71.631       0.390           0.818
# 3        2577.3      8.672     111.010    69.900       0.385           0.815
# 4        2577.4      8.672     110.797    69.040       0.382           0.824
# ...         ...        ...         ...       ...         ...             ...
# 9995     3576.5      8.750      75.086     9.272       0.146           1.694
# 9996     3576.6      8.750      75.118     9.251       0.143           1.703
# 9997     3576.7      8.750      75.077     9.017       0.143           1.711
# 9998     3576.8      8.750      74.947     8.652       0.146           1.725
# 9999     3576.9      8.703      74.814     9.180       0.152           1.731
#
# ...

# %%
style.use('fast')
         
fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(20,30), sharey=True)
fig.subplots_adjust(top=0.75,wspace=0.2)
fig.patch.set_facecolor('white')
fig.patch.set_alpha(1)


#gr & calliper logs 

ax[0].patch.set_facecolor('white')
ax[0].patch.set_alpha(1)
ax01=ax[0].twiny()
ax01.grid(True)
ax01.set_xlim(0,120)
ax01.set_ylim(2577.0,3576.9)
ax01.spines['top'].set_position(('outward',0))
ax01.spines['top'].set_color('black')
ax01.spines['top'].set_linewidth(2)
ax01.set_xlabel('GR (API)',color='red',labelpad=20,fontsize='25')
ax[0].set_ylabel('DEPTH',color='Black',labelpad=20,fontsize='25') 
ax01.tick_params(axis='x', colors='black')
ax01.xaxis.set_major_locator(MultipleLocator(40))
ax01.yaxis.set_major_locator(MultipleLocator(40))
plt.grid(b=True , which='major', color='black', linestyle='-',linewidth='0')

ax01.plot(df['GR (API)'] ,df['Depth (m)'],color='red',linewidth='1')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)



ax02=ax[0].twiny()
ax02.set_xlim(8.4,9.0)
ax02.spines['bottom'].set_color('black')
ax02.spines['left'].set_color('black')
ax02.spines['left'].set_linewidth(2)
ax02.spines['bottom'].set_linewidth(2)
ax02.spines['top'].set_linewidth(2)
ax02.spines['right'].set_linewidth(2)
ax02.spines['right'].set_color('black')
ax02.spines['top'].set_position(('outward',80))
ax02.set_xlabel('CALI (in)',color='black',labelpad=20,fontsize='25')    
ax02.tick_params(axis='x', colors='black')
ax02.spines['top'].set_linewidth(2)
ax02.spines['top'].set_color('black')
ax02.yaxis.set_major_locator(MultipleLocator(40))
ax02.plot(df['CALI (in)'] ,df['Depth (m)'],color='black',linewidth='1')
plt.grid(b=True , which='major', color='black', linestyle='-',linewidth='0.5')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

#Resistivity (ohm m) 
 
ax[1].patch.set_facecolor('white')
ax[1].patch.set_alpha(1)  

ax11=ax[1].twiny()
ax11.grid(True)
ax11.set_xlim(0.1,100)
ax11.set_xscale('log')
ax11.spines['top'].set_position(('outward',0))
ax11.spines['top'].set_color('black')
ax11.spines['top'].set_linewidth(2)
ax11.spines['bottom'].set_linewidth(2)
ax11.spines['bottom'].set_color('black')
ax11.spines['left'].set_color('black')
ax11.spines['left'].set_linewidth(2)
ax11.spines['right'].set_linewidth(2)
ax11.spines['right'].set_color('black')
ax11.set_xlabel('RT (ohm.m)',color='blue',labelpad=20,fontsize='20')    
ax11.tick_params(axis='x', colors='black')
ax11.yaxis.set_major_locator(MultipleLocator(40))
plt.grid(b=True, which='major', color='black', linestyle='-',linewidth='0.5')
plt.minorticks_on()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.grid(b=True, which='minor', color='black', linestyle='-',linewidth='0.3')
ax11.plot(df['RT (ohm.m)'] ,df['Depth (m)'],color='blue',linewidth='2')

ax22=ax[1].twiny()
ax22.grid(True)
ax22.set_xlim(0.1,100)
ax22.set_xscale('log')
ax22.spines['top'].set_position(('outward',80))
ax22.spines['top'].set_color('black')
ax22.spines['top'].set_linewidth(2)
ax22.spines['bottom'].set_linewidth(2)
ax22.spines['bottom'].set_color('black')
ax22.spines['left'].set_color('black')
ax22.spines['left'].set_linewidth(2)
ax22.spines['right'].set_linewidth(2)
ax22.spines['right'].set_color('black')
ax22.set_xlabel('RACEHM (ohm.m)',color='green',labelpad=20,fontsize='20')    
ax22.tick_params(axis='x', colors='black')
ax22.yaxis.set_major_locator(MultipleLocator(40))
plt.grid(b=True, which='major', color='black', linestyle='-',linewidth='0.5')
plt.minorticks_on()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

ax22.plot(df['RACEHM (ohm.m)'] ,df['Depth (m)'],color='green',linewidth='1')

ax33=ax[1].twiny()
ax33.grid(True)
ax33.set_xlim(0.1,100)
ax33.set_xscale('log')
ax33.spines['top'].set_position(('outward',160))
ax33.spines['top'].set_color('black')
ax33.spines['top'].set_linewidth(2)
ax33.spines['bottom'].set_linewidth(2)
ax33.spines['bottom'].set_color('black')
ax33.spines['left'].set_color('black')
ax33.spines['left'].set_linewidth(2)
ax33.spines['right'].set_linewidth(2)
ax33.spines['right'].set_color('black')
ax33.set_xlabel('RACELM (ohm.m)',color='orange',labelpad=20,fontsize='20')    
ax33.tick_params(axis='x', colors='black')
ax33.yaxis.set_major_locator(MultipleLocator(40))
plt.grid(b=True, which='major', color='black', linestyle='-',linewidth='0.5')
plt.minorticks_on()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax33.plot(df['RACELM (ohm.m)'] ,df['Depth (m)'],color='orange',linewidth='1')


ax44=ax[1].twiny()
ax44.grid(True)
ax44.set_xlim(0.1,100)
ax44.set_xscale('log')
ax44.spines['top'].set_position(('outward',240))
ax44.spines['top'].set_color('black')
ax44.spines['top'].set_linewidth(2)
ax44.spines['bottom'].set_linewidth(2)
ax44.spines['bottom'].set_color('black')
ax44.spines['left'].set_color('black')
ax44.spines['left'].set_linewidth(2)
ax44.spines['right'].set_linewidth(2)
ax44.spines['right'].set_color('black')
ax44.set_xlabel('RPCEHM (ohm.m)',color='red',labelpad=20,fontsize='20')    
ax44.tick_params(axis='x', colors='black')
ax44.yaxis.set_major_locator(MultipleLocator(40))
plt.grid(b=True, which='major', color='black', linestyle='-',linewidth='0.5')
plt.minorticks_on()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax44.plot(df['RPCEHM (ohm.m)'] ,df['Depth (m)'],color='red',linewidth='1')

ax55=ax[1].twiny()
ax55.grid(True)
ax55.set_xlim(0.1,100)
ax55.set_xscale('log')
ax55.spines['top'].set_position(('outward',320))
ax55.spines['top'].set_color('black')
ax55.spines['top'].set_linewidth(2)
ax55.spines['bottom'].set_linewidth(2)
ax55.spines['bottom'].set_color('black')
ax55.spines['left'].set_color('black')
ax55.spines['left'].set_linewidth(2)
ax55.spines['right'].set_linewidth(2)
ax55.spines['right'].set_color('black')
ax55.set_xlabel('RPCELM (ohm.m)',color='grey',labelpad=20,fontsize='20')    
ax55.tick_params(axis='x', colors='black')
ax55.yaxis.set_major_locator(MultipleLocator(40))
plt.grid(b=True, which='major', color='black', linestyle='-',linewidth='0.5')
plt.minorticks_on()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax55.plot(df['RPCELM (ohm.m)'] ,df['Depth (m)'],color='grey',linewidth='1')

#Porosity (%) and #RHOB (g/cc.)
 
ax[2].patch.set_facecolor('white')
ax[2].patch.set_alpha(1)
    
ax21=ax[2].twiny()
ax21.grid(True)
ax21.set_xlim(0.45, -0.15)
ax21.spines['top'].set_position(('outward',0))
ax21.spines['top'].set_color('black')
ax21.spines['top'].set_linewidth(2)
ax21.spines['bottom'].set_linewidth(2)
ax21.spines['bottom'].set_color('black')
ax21.spines['left'].set_color('black')
ax21.spines['left'].set_linewidth(2)
ax21.spines['right'].set_linewidth(2)
ax21.spines['right'].set_color('black')
ax21.set_xlabel('Neutron Porosity (%)',color='brown',labelpad=20,fontsize='20')    
ax21.tick_params(axis='x', colors='black')
ax21.xaxis.set_major_locator(MultipleLocator(.15))
ax21.yaxis.set_major_locator(MultipleLocator(40))
plt.grid(b=True, which='major', color='black', linestyle='-',linewidth='0.5')
plt.minorticks_on()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax21.plot(df['NPHI (v/v)'] ,df['Depth (m)'],color='brown',linewidth='1')





ax22=ax[2].twiny()
ax22.grid(True)
ax22.set_xlim(1.95, 2.95)
ax22.spines['top'].set_position(('outward',80))
ax22.spines['top'].set_color('black')
ax22.spines['top'].set_linewidth(2)
ax22.spines['bottom'].set_linewidth(2)
ax22.spines['bottom'].set_color('black')
ax22.spines['left'].set_color('black')
ax22.spines['left'].set_linewidth(2)
ax22.spines['right'].set_linewidth(2)
ax22.spines['right'].set_color('black')
ax22.set_xlabel('Bulk Density (g/cc.)',color='teal',labelpad=20,fontsize='20')    
ax22.tick_params(axis='x', colors='black')
ax22.xaxis.set_major_locator(MultipleLocator(.2))
ax22.yaxis.set_major_locator(MultipleLocator(40))
plt.grid(b=True, which='major', color='black', linestyle='-',linewidth='0')
plt.minorticks_on()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

ax22.plot(df['RHOB (g/cm3)'] ,df['Depth (m)'],color='grey',linewidth='1')
ax[2].fill_betweenx(df['NPHI (v/v)'], df['RHOB (g/cm3)'])



#delta T (usec/ft.)

ax[3].patch.set_facecolor('white')
ax[3].patch.set_alpha(1)
    
ax31=ax[3].twiny()
ax31.grid(True)
ax31.set_xlim(0,200)
ax31.spines['top'].set_position(('outward',0))
ax31.spines['top'].set_color('black')
ax31.spines['top'].set_linewidth(2)
ax31.spines['bottom'].set_linewidth(2)
ax31.spines['bottom'].set_color('black')
ax31.spines['left'].set_color('black')
ax31.spines['left'].set_linewidth(2)
ax31.spines['right'].set_linewidth(2)
ax31.spines['right'].set_color('black')
ax31.set_xlabel('Sonic (μsec/ft.)',color='green',labelpad=20,fontsize='20')    
ax31.tick_params(axis='x', colors='black')
ax31.xaxis.set_major_locator(MultipleLocator(40))
ax31.yaxis.set_major_locator(MultipleLocator(40))
plt.grid(b=True, which='major', color='black', linestyle='-',linewidth='0.5')
plt.minorticks_on()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.grid(b=True, which='minor', color='black', linestyle='-',linewidth='.5')
ax31.plot(df['DT (us/ft)'] ,df['Depth (m)'],color='green',linewidth='1.5')


plt.gca().invert_yaxis()
